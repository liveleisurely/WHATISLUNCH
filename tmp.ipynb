# %%
import pandas as pd
import json
from pandas import json_normalize

# %%
file_path = r"C:\restaurant-form\public\restaurants.json"

# JSON 파일을 읽어옵니다.
with open(file_path, 'r') as file:
    json_data = json.load(file)

# %%
json_data
# Out:
# {'restaurants': [{'name': '연어초밥',
#    'menu': '초밥, 알밥',
#    'category': '일식',
#    'price_range': '11000~15000원',
#    'latitude': 37.5572679,
#    'longitude': 126.9433882,
#    'distance': '474'},
#   {'name': '불밥',
#    'menu': '(돼지고기,오징어,닭) 볶음 1인당 선택가능',
#    'category': '한식',
#    'price_range': '10000원~',
#    'latitude': 37.5588434,
#    'longitude': 126.9464048,
#    'distance': '156'},
#   {'name': '빗갈',
#    'menu': '육회비빔밥',
#    'category': '한식',
#    'price_range': '6000원~8000원',
#    'latitude': 37.55856240000001,
#    'longitude': 126.9384466,
#    'distance': '845'},
#   {'name': '삭',
#    'menu': '튀김, 떡볶이, 순대, 어묵',
#    'category': '분식',
#    'price_range': '정보부족',
#    'latitude': 37.5580752,
#    'longitude': 126.9450861,
#    'distance': '299'},
#   {'name': '김가네',
#    'menu': '김밥, 라면, 우동 등',
#    'category': '분식',
#    'price_range': '5000원 ~ 10000원',
#    'latitude': 37.5588126,
#    'longitude': 126.943937,
#    'distance': '362'},
#   {'name': '단풍나무',
# ...

# %%
# JSON 열을 확장하여 각각의 열로 분리
expanded_df = pd.json_normalize(df['restaurants'])

# 결과 출력
expanded_df.to_csv('./df.csv',encoding='utf-8-sig')

# %%
expanded_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         33 non-null     object
#  1   menu         33 non-null     object
#  2   category     33 non-null     object
#  3   price_range  33 non-null     object
#  4   latitude     33 non-null     float64
#  5   longitude    33 non-null     float64
#  6   distance     33 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 1.9+ KB

# %%
expanded_df.columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 expanded_df.columns()
#
# TypeError: 'Index' object is not callable
